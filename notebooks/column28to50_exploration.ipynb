# %% [markdown]
# # Exploration of columns 28-50
# Columns and their description from data dictionary:
#
# neighbourhood (text) - The neighbourhood
#
# neighbourhood_cleansed	(text)(calculated)	The neighbourhood as geocoded using the latitude and longitude against neighborhoods as defined by open or public digital shapefiles.
#
# neighbourhood_group_cleansed	(text)(calculated)	The neighbourhood group as geocoded using the latitude and longitude against neighborhoods as defined by open or public digital shapefiles.
#
# latitude	(numeric)	Uses the World Geodetic System (WGS84) projection for latitude and longitude.
#
# longitude	(numeric)	Uses the World Geodetic System (WGS84) projection for latitude and longitude.
#
# property_type	(text)		Self selected property type. Hotels and Bed and Breakfasts are described as such by their hosts in this field
#
# room_type	(text)		"[Entire home/apt|Private room|Shared room|Hotel]
#
# accommodates	(integer)		The maximum capacity of the listing
#
# bathrooms	(numeric)		The number of bathrooms in the listing
#
# bathrooms_text	(string	)	"The number of bathrooms in the listing. On the Airbnb web-site, the bathrooms field has evolved from a number to a textual description. For older scrapes, bathrooms is used."
#
# bedrooms	(integer)		The number of bedrooms
#
# beds	(integer)		The number of bed(s)
#
# amenities	(json)
#
# price	(currency)		daily price in local currency
#
# minimum_nights	(integer)		minimum number of night stay for the listing (calendar rules may be different)
#
# maximum_nights	(integer)		maximum number of night stay for the listing (calendar rules may be different)
#
# minimum_minimum_nights	(integer)(calculated)	the smallest minimum_night value from the calender (looking 365 nights in the future)
#
# maximum_minimum_nights	(integer)(calculated)	the largest minimum_night value from the calender (looking 365 nights in the future)
#
# minimum_maximum_nights	(integer)(calculated)	the smallest maximum_night value from the calender (looking 365 nights in the future)
#
# maximum_maximum_nights	(integer)(calculated)	the largest maximum_night value from the calender (looking 365 nights in the future)
#
# minimum_nights_avg_ntm	(numeric)(calculated)	the average minimum_night value from the calender (looking 365 nights in the future)
#
# maximum_nights_avg_ntm	(numeric)(calculated)	the average maximum_night value from the calender (looking 365 nights in the future)
#
# calendar_updated	(date)

# %%
import pandas as pd

csv_file="Data\\raw\\listings.csv"

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file, usecols=range(27,50))

pd.set_option('display.max_columns', None)

# %%
#Check if the right columns are loaded
list(data.columns)
# Out:
# ['neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated']

# %%
data.head
# Out:
# <bound method NDFrame.head of                              neighbourhood neighbourhood_cleansed  \
# 0                          Prague, Czechia                Praha 1
# 1          Prague, Czech Republic, Czechia                Praha 1
# 2                                      NaN                Praha 1
# 3      Prague, Hlavní město Praha, Czechia                Praha 1
# 4          Prague, Czech Republic, Czechia                Praha 1
# ...                                    ...                    ...
# 8944                                   NaN                Praha 5
# 8945  Praha 5, Hlavní město Praha, Czechia                Praha 5
# 8946                                   NaN                Praha 1
# 8947                                   NaN                Praha 1
# 8948                                   NaN                Praha 1
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# 0                              NaN  50.084110  14.430470
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8949 entries, 0 to 8948
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   neighbourhood                 4904 non-null   object
#  1   neighbourhood_cleansed        8949 non-null   object
#  2   neighbourhood_group_cleansed  0 non-null      float64
#  3   latitude                      8949 non-null   float64
#  4   longitude                     8949 non-null   float64
#  5   property_type                 8949 non-null   object
#  6   room_type                     8949 non-null   object
#  7   accommodates                  8949 non-null   int64
#  8   bathrooms                     0 non-null      float64
#  9   bathrooms_text                8933 non-null   object
#  10  bedrooms                      7030 non-null   float64
#  11  beds                          8833 non-null   float64
# ...

# %%
data.describe()
# Out:
#        neighbourhood_group_cleansed     latitude    longitude  accommodates  \
# count                           0.0  8949.000000  8949.000000   8949.000000
# mean                            NaN    50.080928    14.430210      3.929378
# std                             NaN     0.017056     0.032769      2.492711
# min                             NaN    49.947830    14.271417      1.000000
# 25%                             NaN    50.074959    14.418159      2.000000
# 50%                             NaN    50.081696    14.428581      4.000000
# 75%                             NaN    50.089020    14.442960      5.000000
# max                             NaN    50.170570    14.684160     16.000000
#
#        bathrooms     bedrooms         beds  minimum_nights  maximum_nights  \
# count        0.0  7030.000000  8833.000000     8949.000000     8949.000000
# mean         NaN     1.568706     2.612816        4.971952      590.464298
# ...

# %% [markdown]
# Exploring the categorical columns

# %%
# Exploring rows of the columns 
data["calendar_updated"][:20]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: calendar_updated, dtype: float64

# %%
data["neighbourhood"].value_counts()
data["bathrooms"].value_counts()
data["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    7185
# Private room       1477
# Hotel room          161
# Shared room         126
# Name: count, dtype: int64

# %%
#Exploring unique values of various columns
data["neighbourhood_cleansed"].unique()
# Out:
# array(['Praha 1', 'Praha 2', 'Praha 3', 'Praha 7', 'Praha 5', 'Praha 8',
#        'Praha 17', 'Praha 15', 'Praha 6', 'Praha 9', 'Praha 10',
#        'Praha 4', 'Praha 14', 'Praha 13', 'Velká Chuchle', 'Dolní Chabry',
#        'Praha 22', 'Kunratice', 'Zličín', 'Dubeč', 'Zbraslav',
#        'Petrovice', 'Praha 21', 'Suchdol', 'Praha 12', 'Praha 11',
#        'Praha 16', 'Klánovice', 'Šeberov', 'Újezd', 'Štěrboholy',
#        'Kolovraty', 'Řeporyje', 'Ďáblice', 'Slivenec', 'Dolní Počernice',
#        'Lysolaje', 'Libuš', 'Praha 18', 'Praha 20', 'Troja', 'Praha 19',
#        'Koloděje', 'Březiněves', 'Nebušice', 'Satalice', 'Čakovice',
#        'Lipence', 'Dolní Měcholupy', 'Vinoř', 'Nedvězí',
#        'Přední Kopanina'], dtype=object)

# %%
data["neighbourhood"].unique()
data["property_type"].unique()
data["bathrooms_text"].unique()
# Out:
# array(['1.5 baths', '1 bath', '1.5 shared baths', '0 baths', '2 baths',
#        '2.5 baths', '1 private bath', '8 shared baths', '1 shared bath',
#        '3 baths', 'Half-bath', '3.5 baths', '2 shared baths', nan,
#        '4 baths', '5 baths', '10 shared baths', '2.5 shared baths',
#        '3 shared baths', '12 shared baths', '6 baths', '9 baths',
#        'Private half-bath', '5.5 baths', '12 baths', '4.5 baths',
#        '3.5 shared baths', '11 shared baths', '0 shared baths',
#        '6.5 baths', '11.5 shared baths', '7.5 baths', '10 baths',
#        'Shared half-bath', '4 shared baths'], dtype=object)

# %%
data["neighbourhood_group_cleansed"].unique()
# Out:
# array([nan])

# %% [markdown]
# ### Columns to be chosen for the model:

# %% [markdown]
# Columns to be dropped:
#
# neighbourhood - bad data quality, a lot of missing values, inconsistent; neighbourhood_cleansed is sufficient
#
# neighbourhood_group_cleansed - only NaN values
#
# latitude - not useful
#
# longitude - not useful
#
# property_type? - 40+ categories
#
# bathrooms - only NaN values
#
# minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm - not useful data
#
# calendar_updated - only NaN

# %% [markdown]
# Useful columns:
#
# neighbourhood_cleansed - městské části, šlo by sjednotit do správních obvodů pro méně kategorií, 57 -> 21
#
# room type: counts: Entire home/apt    7185, Private room       1477, Hotel room          161, Shared room         126
#
# accomodates - min 1, max 16, mean 3.9
#
# bathrooms_text - a lot of inconsistent categories, number can be extracted
#
# bedrooms - min 1, median 1, max 34, mean 1.5, but 1919 missing values
#
# beds - min 1, median 2, max 50, mean 2.61, 116 missing values
#
# amenities - features need to be extracted
#
# price - change datatype
#
# minimum_nights - min 1, median 2, max 1115, mean 4.97
#
# maximum_nights - min 1, median 365, max 9000, mean 464.41

# %% [markdown]
# ## Data preparation

# %%
data["bathrooms_text"][:50]
# Out:
# 0            1.5 baths
# 1               1 bath
# 2               1 bath
# 3            1.5 baths
# 4               1 bath
# 5               1 bath
# 6               1 bath
# 7               1 bath
# 8               1 bath
# 9               1 bath
# 10              1 bath
# 11              1 bath
# 12           1.5 baths
# 13              1 bath
# 14              1 bath
# 15              1 bath
# 16              1 bath
# 17           1.5 baths
# 18    1.5 shared baths
# 19              1 bath
# 20              1 bath
# 21              1 bath
# 22              1 bath
# 23             0 baths
# 24              1 bath
# 25              1 bath
# 26              1 bath
# 27              1 bath
# 28              1 bath
# 29              1 bath
# 30              1 bath
# 31              1 bath
# 32              1 bath
# 33              1 bath
# 34              1 bath
# 35              1 bath
# 36              1 bath
# 37              1 bath
# 38             2 baths
# 39              1 bath
# ...

# %%
import numpy as np
import re

#Getting the numeric values from bathrooms_text
def extract_numerical_value(text):
    # Regular expression pattern to match numerical values
    pattern = r'(\d+(\.\d+)?)'  # Matches one or more digits, possibly followed by a decimal point and more digits
    matches = re.findall(pattern, str(text))
    if matches:
        return float(matches[0][0])  # Extracting the numerical value and converting it to float
    else:
        return np.nan  # Return NaN if no numerical value is found

data["bathrooms_numeric"] = data['bathrooms_text'].apply(extract_numerical_value)
data["bathrooms_numeric"] = data["bathrooms_numeric"].astype(float)
data["bathrooms_numeric"][:50]

#We could also create categories such as "0 baths", "1 bath", "2 baths", "3+ baths"
# Out:
# 0     1.5
# 1     1.0
# 2     1.0
# 3     1.5
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.5
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.5
# 18    1.5
# 19    1.0
# 20    1.0
# 21    1.0
# 22    1.0
# 23    0.0
# 24    1.0
# 25    1.0
# 26    1.0
# 27    1.0
# 28    1.0
# 29    1.0
# 30    1.0
# 31    1.0
# 32    1.0
# 33    1.0
# 34    1.0
# 35    1.0
# 36    1.0
# 37    1.0
# 38    2.0
# 39    1.0
# 40    2.0
# 41    1.0
# 42    2.5
# 43    2.0
# 44    1.0
# 45    1.5
# 46    1.0
# 47    1.0
# 48    1.0
# 49    1.0
# Name: bathrooms_numeric, dtype: float64

# %%
# Creating a binary column which indicates whether bathroom is shared (1) or not (0)
def extract_shared(text):
    if pd.isnull(text):
        return 0  # Return 0 if the value is NaN
    elif 'shared' in text.lower():
        return 1  # Return 1 if the word "shared" is found
    else:
        return 0  # Return 0 otherwise
data["bathrooms_shared"] = data['bathrooms_text'].apply(extract_shared)
data["bathrooms_shared"] = data['bathrooms_shared'].astype('category')
data["bathrooms_shared"].value_counts()
# Out:
# bathrooms_shared
# 0    8088
# 1     861
# Name: count, dtype: int64

# %%
#Creating a dataframe with only desired columns
columns_to_keep = ["neighbourhood_cleansed","room_type", "accommodates", "bathrooms_numeric", "bedrooms", "beds", "amenities", "price", "minimum_nights", "maximum_nights", "bathrooms_shared"]
data_relevant = data[columns_to_keep]

# %%
#Removing $ symbol and comma from price to be able to change its datatype to float
data_relevant["price"] = data_relevant["price"].str.replace('$', '')
data_relevant["price"] = data_relevant["price"].str.replace(',', '')
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\635088690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_relevant["price"] = data_relevant["price"].str.replace('$', '')
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\635088690.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_relevant["price"] = data_relevant["price"].str.replace(',', '')

# %%
data_relevant["price"] = data_relevant["price"].astype(float)
data_relevant["price"][:10]
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\1853836529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_relevant["price"] = data_relevant["price"].astype(float)
# 0    1449.0
# 1    3340.0
# 2    2579.0
# 3    2633.0
# 4    5919.0
# 5    3070.0
# 6    1628.0
# 7    1572.0
# 8    1600.0
# 9    1372.0
# Name: price, dtype: float64

# %%
data['neighbourhood_cleansed'].unique()
# Out:
# array(['Praha 1', 'Praha 2', 'Praha 3', 'Praha 7', 'Praha 5', 'Praha 8',
#        'Praha 17', 'Praha 15', 'Praha 6', 'Praha 9', 'Praha 10',
#        'Praha 4', 'Praha 14', 'Praha 13', 'Velká Chuchle', 'Dolní Chabry',
#        'Praha 22', 'Kunratice', 'Zličín', 'Dubeč', 'Zbraslav',
#        'Petrovice', 'Praha 21', 'Suchdol', 'Praha 12', 'Praha 11',
#        'Praha 16', 'Klánovice', 'Šeberov', 'Újezd', 'Štěrboholy',
#        'Kolovraty', 'Řeporyje', 'Ďáblice', 'Slivenec', 'Dolní Počernice',
#        'Lysolaje', 'Libuš', 'Praha 18', 'Praha 20', 'Troja', 'Praha 19',
#        'Koloděje', 'Březiněves', 'Nebušice', 'Satalice', 'Čakovice',
#        'Lipence', 'Dolní Měcholupy', 'Vinoř', 'Nedvězí',
#        'Přední Kopanina'], dtype=object)

# %%
# Unified neighbourhoods
mapping = {
    'Velká Chuchle': 'Praha 16',
    'Dolní Chabry': 'Praha 8',
    'Kunratice': 'Praha 4',
    'Zličín': 'Praha 17',
    'Dubeč': 'Praha 15',
    'Zbraslav': 'Praha 16',
    'Petrovice': 'Praha 15',
    'Suchdol': 'Praha 6',
    'Klánovice': 'Praha 21',
    'Šeberov': 'Praha 11',
    'Újezd': 'Praha 11',
    'Štěrboholy': 'Praha 15',
    'Kolovraty': 'Praha 22',
    'Řeporyje': 'Praha 13',
    'Ďáblice': 'Praha 8',
    'Slivenec': 'Praha 5',
    'Dolní Počernice': 'Praha 14',
    'Koloděje': 'Praha 21',
    'Březiněves': 'Praha 8',
    'Nebušice': 'Praha 6',
    'Satalice': 'Praha 19',
    'Čakovice': 'Praha 18',
    'Lipence': 'Praha 16',
    'Dolní Měcholupy': 'Praha 15',
    'Vinoř': 'Praha 19',
    'Nedvězí': 'Praha 22',
    'Přední Kopanina': 'Praha 6',
    'Lysolaje': 'Praha 6',
    'Libuš': 'Praha 12',
    'Troja': 'Praha 7'
}

# Iterate over items in the mapping dictionary and replace values
data_relevant['neighbourhood_cleansed'] = data['neighbourhood_cleansed'].apply(lambda x: mapping[x] if x in mapping else x)

data_relevant['neighbourhood_cleansed'].unique()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\2805849192.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_relevant['neighbourhood_cleansed'] = data['neighbourhood_cleansed'].apply(lambda x: mapping[x] if x in mapping else x)
# array(['Praha 1', 'Praha 2', 'Praha 3', 'Praha 7', 'Praha 5', 'Praha 8',
#        'Praha 17', 'Praha 15', 'Praha 6', 'Praha 9', 'Praha 10',
#        'Praha 4', 'Praha 14', 'Praha 13', 'Praha 16', 'Praha 22',
#        'Praha 21', 'Praha 12', 'Praha 11', 'Praha 18', 'Praha 20',
#        'Praha 19'], dtype=object)

# %%
#removing outliers
data_filtered = data_relevant[data_relevant['price'] < data_relevant['price'].quantile(0.95)]

# %% [markdown]
# Amenities

# %%
#Printing all the unique amenities
import json

data_filtered['amenities'] = data_filtered['amenities'].apply(lambda x: json.loads(x))
all_amenities = [amenity for amenities_list in data_filtered['amenities'] for amenity in amenities_list]
unique_amenities = set(all_amenities)
unique_amenities
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\3548591498.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered['amenities'] = data_filtered['amenities'].apply(lambda x: json.loads(x))
# {'Concept oven',
#  '21" TV with standard cable',
#  'Lake access',
#  'Dryer',
#  'Free parking on premises – 1 space',
#  'Pioneer sound system with Bluetooth and aux',
#  'Botanica shampoo',
#  'Bio Oliveoil body soap',
#  'Simens induction stove',
#  'PRIJA shampoo',
#  'Garnier shampoo',
#  'Zara body soap',
#  'Clothing storage: closet and dresser',
#  '28" HDTV',
#  'TV with standard cable, premium cable',
#  'ALDA conditioner',
#  'HDTV with Apple TV, HBO Max, Netflix',
#  'Manufaktura - best typical Czech cosmetics shampoo',
# ...

# %%
#Unfortunately there are 1933 unique amenities, names are not unified / standardised
len(unique_amenities)
# Out:
# 1933

# %%
# Creating a new column for the number of amenities in each airbnb
data_filtered["amenities_num"] = data_filtered["amenities"].apply(len)
data_filtered["amenities_num"][:20]
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\2767110841.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered["amenities_num"] = data_filtered["amenities"].apply(len)
# 0     21
# 1     30
# 2     27
# 3     58
# 4     28
# 5     32
# 6     29
# 7     22
# 8     24
# 9     22
# 10    18
# 11    27
# 12    31
# 13    28
# 14    35
# 15    36
# 16    34
# 17    20
# 18    58
# 19    21
# Name: amenities_num, dtype: int64

# %%
# We could also use features indicating whether the most common amenities are present in given listing
from collections import Counter

amenity_counts = Counter(all_amenities)
amenity_counts
# Out:
# Counter({'Kitchen': 7746,
#          'Essentials': 7671,
#          'Wifi': 7648,
#          'Hair dryer': 7125,
#          'Hangers': 6843,
#          'Hot water': 6791,
#          'Dishes and silverware': 6712,
#          'Iron': 6374,
#          'Cooking basics': 6350,
#          'Refrigerator': 6246,
#          'Bed linens': 6144,
#          'Heating': 5748,
#          'Shampoo': 5418,
#          'Microwave': 5035,
#          'Long term stays allowed': 4621,
#          'Smoke alarm': 4585,
#          'Hot water kettle': 4133,
#          'Dedicated workspace': 4130,
#          'Elevator': 4128,
#          'Shower gel': 3910,
#          'Washer': 3904,
#          'Self check-in': 3780,
#          'Fire extinguisher': 3750,
#          'Dining table': 3586,
#          'Room-darkening shades': 3519,
#          'Wine glasses': 3469,
#          'Stove': 3460,
#          'TV': 3452,
#          'Dishwasher': 3431,
#          'Carbon monoxide alarm': 3211,
# ...

# %% [markdown]
# ### Further analysis

# %%
#Splitting the columns by datatype for further analysis
columns_numeric = ["accommodates", "bathrooms_numeric", "bedrooms", "beds", "price", "minimum_nights", "maximum_nights", "amenities_num"]
columns_category = ["neighbourhood_cleansed","room_type", "bathrooms_shared"]
data_numeric = data_filtered[columns_numeric]
data_categorical = data_filtered[columns_category]

# %%
data_numeric.corr()
# Out:
#                    accommodates  bathrooms_numeric  bedrooms      beds  \
# accommodates           1.000000           0.272489  0.514923  0.660444
# bathrooms_numeric      0.272489           1.000000  0.253880  0.413984
# bedrooms               0.514923           0.253880  1.000000  0.482107
# beds                   0.660444           0.413984  0.482107  1.000000
# price                  0.482390           0.067249  0.310221  0.252169
# minimum_nights        -0.016212          -0.006473 -0.004138  0.008995
# maximum_nights         0.104618           0.016112  0.041407  0.060507
# amenities_num          0.169019           0.047471  0.011265  0.009691
#
#                       price  minimum_nights  maximum_nights  amenities_num
# accommodates       0.482390       -0.016212        0.104618       0.169019
# bathrooms_numeric  0.067249       -0.006473        0.016112       0.047471
# bedrooms           0.310221       -0.004138        0.041407       0.011265
# ...

# %% [markdown]
# There is correlation between number of beds, bedrooms and bathrooms and accommodates (how many people can rent the listed property). The biggest correlation for the price is with accommodates (0.48), followed by bedrooms (0.31) and beds (0,25) columns.

# %%
#Calculating missing values
total_rows = len(data_filtered)
missing_values_percentage = (data_filtered.isnull().sum() / total_rows) * 100
missing_values_percentage
# Out:
# neighbourhood_cleansed     0.000000
# room_type                  0.000000
# accommodates               0.000000
# bathrooms_numeric          0.470533
# bedrooms                  21.421009
# beds                       1.105752
# amenities                  0.000000
# price                      0.000000
# minimum_nights             0.000000
# maximum_nights             0.000000
# bathrooms_shared           0.000000
# amenities_num              0.000000
# dtype: float64

# %% [markdown]
# Since bedrooms have 21% of missing values and are highly correlated with beds and accommodates, the column might be dropped

# %%
data_filtered.hist(figsize=(15,15), bins=10)
# Out:
# array([[<Axes: title={'center': 'accommodates'}>,
#         <Axes: title={'center': 'bathrooms_numeric'}>,
#         <Axes: title={'center': 'bedrooms'}>],
#        [<Axes: title={'center': 'beds'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'minimum_nights'}>],
#        [<Axes: title={'center': 'maximum_nights'}>,
#         <Axes: title={'center': 'amenities_num'}>, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming data_filtered is your DataFrame containing categorical columns

# Iterate through each categorical column
for column in data_categorical:
    # Create a countplot
    plt.figure(figsize=(10, 5))
    sns.countplot(data=data_filtered, x=column)
    plt.title(f'Histogram of {column}')
    plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
    plt.show()

# %% [markdown]
# Histograms show there are outliers in a lot of the columns. Most values are similar, so these columns might not be super useful features.

# %%
data_filtered['accommodates_cat'] = pd.cut(data_filtered['accommodates'], bins=[-float("inf"),1,2,4,8,float("inf")], labels=["1","2","3-4","5-7","7+"])

plot = (ggplot(data_filtered, aes(x='accommodates_cat', y='price'))
        + geom_boxplot()
        + labs(x='Capacity of listing', y='Price'))

plot.show()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_23468\168234767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered['accommodates_cat'] = pd.cut(data_filtered['accommodates'], bins=[-float("inf"),1,2,4,8,float("inf")], labels=["1","2","3-4","5-7","7+"])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 3
#       1 data_filtered['accommodates_cat'] = pd.cut(data_filtered['accommodates'], bins=[-float("inf"),1,2,4,8,float("inf")], labels=["1","2","3-4","5-7","7+"])
# ----> 3 plot = (ggplot(data_filtered, aes(x='accommodates_cat', y='price'))
#       4         + geom_boxplot()
# ...

# %%
data_filtered['bathrooms_cat'] = pd.cut(data_filtered['bathrooms_numeric'], bins=[-float("inf"),1,2,4,float("inf")], labels=["1","2","3-4","5+"])

plot = (ggplot(data_filtered, aes(x='bathrooms_cat', y='price'))
        + geom_boxplot()
        + labs(x='Number of bathrooms', y='Price'))

plot.show()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_17204\3112909234.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_filtered['minimum_nights_cat'] = pd.cut(data_filtered['minimum_nights'], bins=[-float("inf"),2,7,14,float("inf")], labels=["1-2","3-7","8-14", "15+"])

plot = (ggplot(data_filtered, aes(x='minimum_nights_cat', y='price'))
        + geom_boxplot()
        + labs(x='Number of minimum nights rentable', y='Price'))

plot.show()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_17204\1023945900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_filtered['maximum_nights_cat'] = pd.cut(data_filtered['maximum_nights'], bins=[-float("inf"),7,30,90,365,float("inf")], labels=["1-7","8-30","30-90", "90-365","365+"])

plot = (ggplot(data_filtered, aes(x='maximum_nights_cat', y='price'))
        + geom_boxplot()
        + labs(x='Number of maximum nights rentable', y='Price'))

plot.show()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_17204\3739825920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_filtered['amenities_num_cat'] = pd.cut(data_filtered['amenities_num'], bins=[-float("inf"),10,20,30,40,float("inf")], labels=["0-10","10-20","30-40", "40-50","50+"])

plot = (ggplot(data_filtered, aes(x='amenities_num_cat', y='price'))
        + geom_boxplot()
        + labs(x='Number of amenities', y='Price'))

plot.show()
# Out:
# C:\Users\Johanka\AppData\Local\Temp\ipykernel_17204\3611094464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plot = (ggplot(data_filtered, aes(x='neighbourhood_cleansed', y='price'))
        + geom_boxplot()
        + labs(x='Neighbourhood', y='Price')
        + theme(axis_text_x = element_text(angle = 90, hjust = 1)))
plot.show()

# %%
plot = (ggplot(data_filtered, aes(x='room_type', y='price'))
        + geom_boxplot()
        + labs(x='Type of accommodation', y='Price')
        )
plot.show()

# %%
plot = (ggplot(data_filtered, aes(x='bathrooms_shared', y='price'))
        + geom_boxplot()
        + labs(x='Shared bathroom no / yes', y='Price')
        )
plot.show()

# %% [markdown]
# The most promising columns in the end are:
#
# neighbourhood - most listings are in Praha 1 and 2, ang generally near the center, where they tend to be more expensive
#
# (bedrooms), beds, accommodates, bathrooms - the more rooms there are / the bigger capacity there is, the more expensive listings are; (beds includes a lot of missing values)
#
# bathrooms_shared - when bathrooms are shared, it significantly affects the price
#
# room_type - category significantly affects price
#
# amenities_num - the more amenities, the pricier
#
# minimum_nights - if the accommodation is meant for longer stays, it tends to be cheaper
#
# Other possible features:
#
# ratio of beds/accommodates to bedrooms

# %% [markdown]
# Next steps for data prep:
#
# deal with missing values
#
# deal with outliers
#
# decide what to do with highly correlated columns
#
# discretization yes or no
#
# one hot encoding or alternative
#
# more features from amenities?

# %%
data_outliers = data_relevant[data_relevant['price'] > data_relevant['price'].quantile(0.95)]
data_outliers.describe()
# Out:
#        accommodates  bathrooms_numeric    bedrooms        beds         price  \
# count    448.000000         443.000000  350.000000  426.000000  4.480000e+02
# mean       5.988839           1.720090    2.542857    4.483568  3.059636e+04
# std        4.450811           1.424011    2.052922    5.394198  1.069613e+05
# min        1.000000           0.000000    1.000000    1.000000  8.827000e+03
# 25%        2.000000           1.000000    1.000000    1.000000  1.100000e+04
# 50%        4.000000           1.000000    2.000000    2.000000  1.402000e+04
# 75%        8.000000           2.000000    3.000000    6.000000  2.453400e+04
# max       16.000000          12.000000   18.000000   50.000000  2.047953e+06
#
#        minimum_nights  maximum_nights
# count      448.000000      448.000000
# mean         9.544643      694.459821
# std         77.308920      459.161090
# min          1.000000        2.000000
# 25%          1.000000      365.000000
# 50%          1.000000     1124.000000
# ...

# %%
data_relevant.describe()
# Out:
#        accommodates  bathrooms_numeric     bedrooms         beds  \
# count   8949.000000        8904.000000  7030.000000  8833.000000
# mean       3.929378           1.309973     1.568706     2.612816
# std        2.492711           0.880956     1.166122     2.458161
# min        1.000000           0.000000     1.000000     1.000000
# 25%        2.000000           1.000000     1.000000     1.000000
# 50%        4.000000           1.000000     1.000000     2.000000
# 75%        5.000000           1.500000     2.000000     3.000000
# max       16.000000          12.000000    34.000000    50.000000
#
#               price  minimum_nights  maximum_nights
# count  8.949000e+03     8949.000000     8949.000000
# mean   3.902617e+03        4.971952      590.464298
# std    2.472325e+04       32.490035      464.412612
# min    2.830000e+02        1.000000        1.000000
# 25%    1.500000e+03        1.000000      180.000000
# 50%    2.193000e+03        2.000000      365.000000
# ...
